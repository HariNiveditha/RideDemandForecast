# %% [markdown]
# <a href="https://colab.research.google.com/github/HariNiveditha/RideDemandForecast/blob/main/data_loading%26cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import userdata

os.environ["KAGGLE_API_TOKEN"] = userdata.get("KAGGLE_API_TOKEN")

# %%
# !pip install -q kaggle

# %%
# !kaggle --version
# Out:
# ...
# Kaggle CLI 2.0.2

# %%
# !pip install -U kaggle
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.2/126.2 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 248.6/248.6 kB 15.9 MB/s eta 0:00:00

# %%
# !kaggle --version

# %%
# !kaggle datasets list -s uber

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_30586/1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
import os

project_path = "/content/drive/MyDrive/RideDemandForecast"

os.makedirs(project_path, exist_ok=True)
# %cd $project_path

# %%
# !kaggle datasets download \
-d shuhengmo/uber-nyc-forhire-vehicles-trip-data-2021 \
-f fhvhv_tripdata_2021-04.parquet

# %%
# !unzip fhvhv_tripdata_2021-04.parquet.zip

# %%
# !rm fhvhv_tripdata_2021-04.parquet.zip

# %%
import pandas as pd

df = pd.read_parquet("fhvhv_tripdata_2021-04.parquet")

print("Rows, Columns:", df.shape)

# %%
df.columns.tolist()

# %%
df.info()

# %%
# !kaggle datasets download \
-d shuhengmo/uber-nyc-forhire-vehicles-trip-data-2021 \
-f fhvhv_tripdata_2021-05.parquet

# %%
# !unzip fhvhv_tripdata_2021-05.parquet.zip

# %%
# !rm fhvhv_tripdata_2021-05.parquet.zip

# %%
# !kaggle datasets download \
-d shuhengmo/uber-nyc-forhire-vehicles-trip-data-2021 \
-f fhvhv_tripdata_2021-06.parquet

# %%
# !unzip fhvhv_tripdata_2021-06.parquet.zip
# !rm fhvhv_tripdata_2021-06.parquet.zip

# %%
# !kaggle datasets files shuhengmo/uber-nyc-forhire-vehicles-trip-data-2021

# %%
# !kaggle datasets download \
-d shuhengmo/uber-nyc-forhire-vehicles-trip-data-2021 \
-f "nyc 2021-01-01 to 2021-12-31.csv"

# %%
# !kaggle datasets download \
-d shuhengmo/uber-nyc-forhire-vehicles-trip-data-2021 \
-f taxi_zone_lookup.csv

# %%
# !ls"

# %%
# !ls

# %%
# !ls -lh *.parquet

# %%
import os

for root, dirs, files in os.walk("/content/drive/MyDrive"):
    if "RideDemandForecast" in root:
        print(root)

# %%
# !find "/content/drive/MyDrive" -type d

# %%
import os
os.path.exists("/content/drive")

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !ls /content/drive/MyDrive

# %%
# !ls -lh /content

# %%
# !ls -lh /content/drive/MyDrive

# %%
# !ls -lh "/content/drive/MyDrive/RideDemandForecast"

# %%
# %cd "/content/drive/MyDrive/RideDemandForecast"

# %%
# !kaggle datasets download \
-d shuhengmo/uber-nyc-forhire-vehicles-trip-data-2021 \
-f fhvhv_tripdata_2021-04.parquet

# %%
# !kaggle datasets download \
-d shuhengmo/uber-nyc-forhire-vehicles-trip-data-2021 \
-f fhvhv_tripdata_2021-05.parquet

# %%
# !kaggle datasets download \
-d shuhengmo/uber-nyc-forhire-vehicles-trip-data-2021 \
-f fhvhv_tripdata_2021-06.parquet

# %%
# !unzip fhvhv_tripdata_2021-04.parquet.zip
# !unzip fhvhv_tripdata_2021-05.parquet.zip
# !unzip fhvhv_tripdata_2021-06.parquet.zip

# %%
# !rm *.zip

# %%
# !mv /content/*.csv "/content/drive/MyDrive/RideDemandForecast/"

# %%
# !ls -lh "/content/drive/MyDrive/RideDemandForecast"

# %%
import pandas as pd

# %%
weather_df = pd.read_csv(
    "/content/drive/MyDrive/RideDemandForecast/nyc%202021-01-01%20to%202021-12-31.csv"
)

zone_df = pd.read_csv(
    "/content/drive/MyDrive/RideDemandForecast/taxi_zone_lookup.csv"
)

# %%
weather_df.head()
weather_df.info()
weather_df.columns

# %%
weather_df = weather_df[
    [
        "datetime",
        "temp",
        "feelslike",
        "humidity",
        "precip",
        "precipprob",
        "snow",
        "windgust",
        "windspeed",
        "sealevelpressure",
        "cloudcover",
        "visibility"
    ]
]

# %%
weather_df = pd.read_csv(
    "/content/drive/MyDrive/RideDemandForecast/nyc%202021-01-01%20to%202021-12-31.csv"
)

# %%
weather_df = weather_df[
    [
        "datetime",
        "address",
        "temp",
        "feelslike",
        "humidity",
        "precip",
        "precipprob",
        "snow",
        "windgust",
        "windspeed",
        "sealevelpressure",
        "cloudcover",
        "visibility"
    ]
]

# %%
print(weather_df["address"].nunique())
print(weather_df["address"].unique())

# %%
weather_df = weather_df[
    [
        "datetime",
        "temp",
        "feelslike",
        "humidity",
        "precip",
        "precipprob",
        "snow",
        "windgust",
        "windspeed",
        "sealevelpressure",
        "cloudcover",
        "visibility"
    ]
]

# %%
weather_df["windgust"] = weather_df["windgust"].fillna(weather_df["windgust"].median())

# %%
weather_df["datetime"] = pd.to_datetime(weather_df["datetime"])

# %%
weather_df["day"] = weather_df["datetime"].dt.day
weather_df["month"] = weather_df["datetime"].dt.month
weather_df["dayofweek"] = weather_df["datetime"].dt.dayofweek
weather_df["weekofyear"] = weather_df["datetime"].dt.isocalendar().week.astype(int)

# %%
weather_df.columns

# %%
weather_df["datetime"] = pd.to_datetime(weather_df["datetime"])

weather_df["year"] = weather_df["datetime"].dt.year
weather_df["hour"] = weather_df["datetime"].dt.hour      # only if hourly data
weather_df["is_weekend"] = (weather_df["dayofweek"] >= 5).astype(int)
weather_df["quarter"] = weather_df["datetime"].dt.quarter
weather_df["dayofyear"] = weather_df["datetime"].dt.dayofyear

# %%
weather_df.duplicated().sum()

# %%
weather_df.isnull().sum()

# %%
weather_df.info()

# %%
weather_df["hour"].nunique()
weather_df["hour"].unique()

# %%
weather_df["year"].unique()

# %%
weather_df.drop(columns=["year", "hour"], inplace=True)

# %%
weather_df.sort_values("datetime", inplace=True)
weather_df.reset_index(drop=True, inplace=True)

# %%
weather_df.describe()

# %%
weather_df.to_parquet("weather_cleaned.parquet", index=False)

# %%
import pandas as pd

april = pd.read_parquet("/content/drive/MyDrive/RideDemandForecast/fhvhv_tripdata_2021-04.parquet")
may = pd.read_parquet("/content/drive/MyDrive/RideDemandForecast/fhvhv_tripdata_2021-05.parquet")
june = pd.read_parquet("/content/drive/MyDrive/RideDemandForecast/fhvhv_tripdata_2021-06.parquet")

# %%
trip_df = pd.concat([april, may, june], ignore_index=True)

# %%
# !cat /proc/meminfo | grep MemTotal
# Out:
# MemTotal:       13286936 kB

# %%
trip_df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_30586/1721488590.py in <cell line: 0>()
# ----> 1 trip_df.info()
#
# NameError: name 'trip_df' is not defined

# %%
print("april" in globals())
print("may" in globals())
print("june" in globals())
# Out:
# False
# False
# False

# %%
import pandas as pd
import numpy as np
import gc

# %%
base_path = "/content/drive/MyDrive/RideDemandForecast"

files = {
    "04": f"{base_path}/fhvhv_tripdata_2021-04.parquet",
    "05": f"{base_path}/fhvhv_tripdata_2021-05.parquet",
    "06": f"{base_path}/fhvhv_tripdata_2021-06.parquet",
}

# %%
def process_month(file_path, month):

    print(f"\nProcessing {month}...")

    # Load parquet
    df = pd.read_parquet(file_path)

    print("Original Shape:", df.shape)

    # Keep only required columns
    df = df[
        [
            "pickup_datetime",
            "PULocationID"
        ]
    ]

    # Remove missing values
    df.dropna(inplace=True)

    # Convert datetime
    df["pickup_datetime"] = pd.to_datetime(df["pickup_datetime"])

    # Round to nearest hour
    df["pickup_hour"] = df["pickup_datetime"].dt.floor("h")

    # Aggregate ride demand
    hourly = (
        df.groupby(["pickup_hour", "PULocationID"])
        .size()
        .reset_index(name="ride_count")
    )

    print("Aggregated Shape:", hourly.shape)

    # Save
    output_file = f"{base_path}/hourly_demand_{month}.parquet"
    hourly.to_parquet(output_file, index=False)

    print("Saved:", output_file)

    # Free memory
    del df
    del hourly
    gc.collect()

# %%
process_month(files["04"], "04")
# Out:
# Processing 04...
# Original Shape: (14111371, 24)
# /tmp/ipykernel_32523/4084725607.py:25: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   df["pickup_hour"] = df["pickup_datetime"].dt.floor("H")
# Aggregated Shape: (181057, 3)
# Saved: /content/drive/MyDrive/RideDemandForecast/hourly_demand_04.parquet

# %%
process_month(files["05"], "05")
# Out:
# Processing 05...
# Original Shape: (14719171, 24)
# Aggregated Shape: (187381, 3)
# Saved: /content/drive/MyDrive/RideDemandForecast/hourly_demand_05.parquet

# %%
process_month(files["06"], "06")
# Out:
# Processing 06...
# Original Shape: (14961892, 24)
# Aggregated Shape: (181859, 3)
# Saved: /content/drive/MyDrive/RideDemandForecast/hourly_demand_06.parquet

# %%
base_path = "/content/drive/MyDrive/RideDemandForecast"

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

base_path = "/content/drive/MyDrive/RideDemandForecast"

print(os.path.exists(base_path))
print(os.listdir(base_path))
# Out:
# True
# ['nyc%202021-01-01%20to%202021-12-31.csv', 'taxi_zone_lookup.csv', 'fhvhv_tripdata_2021-05.parquet', 'fhvhv_tripdata_2021-04.parquet', 'fhvhv_tripdata_2021-06.parquet', 'weather_cleaned.parquet', 'hourly_demand_04.parquet', 'hourly_demand_05.parquet', 'hourly_demand_06.parquet']

# %%
import pandas as pd

april = pd.read_parquet(
    f"{base_path}/hourly_demand_04.parquet"
)

may = pd.read_parquet(
    f"{base_path}/hourly_demand_05.parquet"
)

june = pd.read_parquet(
    f"{base_path}/hourly_demand_06.parquet"
)

trip_df = pd.concat([april, may, june], ignore_index=True)

print(trip_df.shape)
trip_df.head()
# Out:
# (550297, 3)
#   pickup_hour  PULocationID  ride_count
# 0  2021-04-01             3          26
# 1  2021-04-01             4          24
# 2  2021-04-01             6           5
# 3  2021-04-01             7          83
# 4  2021-04-01             9           6

# %%
print(trip_df.dtypes)
print(trip_df["pickup_hour"].head(20))
# Out:
# pickup_hour     datetime64[us]
# PULocationID             int64
# ride_count               int64
# dtype: object
# 0    2021-04-01
# 1    2021-04-01
# 2    2021-04-01
# 3    2021-04-01
# 4    2021-04-01
# 5    2021-04-01
# 6    2021-04-01
# 7    2021-04-01
# 8    2021-04-01
# 9    2021-04-01
# 10   2021-04-01
# 11   2021-04-01
# 12   2021-04-01
# 13   2021-04-01
# 14   2021-04-01
# 15   2021-04-01
# 16   2021-04-01
# 17   2021-04-01
# 18   2021-04-01
# 19   2021-04-01
# Name: pickup_hour, dtype: datetime64[us]

# %%
print(trip_df["pickup_hour"].dt.hour.value_counts().sort_index())
# Out:
# pickup_hour
# 0     22871
# 1     22580
# 2     22294
# 3     21934
# 4     22022
# 5     22486
# 6     22721
# 7     22919
# 8     22974
# 9     23013
# 10    23072
# 11    23095
# 12    23148
# 13    23185
# 14    23255
# 15    23286
# 16    23271
# 17    23273
# 18    23252
# 19    23242
# 20    23179
# 21    23139
# 22    23068
# 23    23018
# Name: count, dtype: int64

# %%
trip_df.sort_values(
    ["pickup_hour", "PULocationID"],
    inplace=True
)

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
zone_df = pd.read_csv(
    "/content/drive/MyDrive/RideDemandForecast/taxi_zone_lookup.csv"
)

# %%
zone_df.head()
zone_df.info()
zone_df.isnull().sum()
zone_df.duplicated().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265 entries, 0 to 264
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   LocationID    265 non-null    int64
#  1   Borough       265 non-null    object
#  2   Zone          264 non-null    object
#  3   service_zone  263 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 8.4+ KB
# np.int64(0)

# %%
zone_df[zone_df["Zone"].isnull()]
# Out:
#      LocationID  Borough Zone service_zone
# 264         265  Unknown  NaN          NaN

# %%
zone_df[zone_df["service_zone"].isnull()]
# Out:
#      LocationID  Borough Zone service_zone
# 263         264  Unknown   NV          NaN
# 264         265  Unknown  NaN          NaN

# %%
zone_df[zone_df.isnull().any(axis=1)]
# Out:
#      LocationID  Borough Zone service_zone
# 263         264  Unknown   NV          NaN
# 264         265  Unknown  NaN          NaN

# %%
import os

base_path = "/content/drive/MyDrive/RideDemandForecast"

print(os.path.exists(base_path))
print(os.listdir(base_path))
# Out:
# True
# ['data_loading&cleaning.ipynb', 'nyc%202021-01-01%20to%202021-12-31.csv', 'taxi_zone_lookup.csv', 'fhvhv_tripdata_2021-05.parquet', 'fhvhv_tripdata_2021-04.parquet', 'fhvhv_tripdata_2021-06.parquet', 'weather_cleaned.parquet', 'hourly_demand_04.parquet', 'hourly_demand_05.parquet', 'hourly_demand_06.parquet', 'EDA.ipynb']

# %%
import pandas as pd

april = pd.read_parquet(
    f"{base_path}/hourly_demand_04.parquet"
)

may = pd.read_parquet(
    f"{base_path}/hourly_demand_05.parquet"
)

june = pd.read_parquet(
    f"{base_path}/hourly_demand_06.parquet"
)

trip_df = pd.concat([april, may, june], ignore_index=True)

# %%
print(
    trip_df[trip_df["PULocationID"].isin([264, 265])]
    [["PULocationID", "ride_count"]]
    .head()
)

print(
    trip_df["PULocationID"].isin([264, 265]).sum()
)
# Out:
#       PULocationID  ride_count
# 250            265           1
# 736            265           2
# 1219           265           1
# 1468           265           2
# 1715           265           1
# 1584

# %%
trip_df[trip_df["PULocationID"].isin([264, 265])]["PULocationID"].value_counts()
# Out:
# PULocationID
# 265    1582
# 264       2
# Name: count, dtype: int64

# %%
zone_df["Zone"] = zone_df["Zone"].fillna("Unknown")
zone_df["service_zone"] = zone_df["service_zone"].fillna("Unknown")

# %%
zone_df.isnull().sum()
# Out:
# LocationID      0
# Borough         0
# Zone            0
# service_zone    0
# dtype: int64

# %%
zone_df[zone_df["LocationID"].isin([264, 265])]
# Out:
#      LocationID  Borough     Zone service_zone
# 263         264  Unknown       NV      Unknown
# 264         265  Unknown  Unknown      Unknown

# %%
trip_df = trip_df.merge(
    zone_df[["LocationID", "Borough", "Zone", "service_zone"]],
    left_on="PULocationID",
    right_on="LocationID",
    how="left"
)

trip_df.drop(columns=["LocationID"], inplace=True)

# %%
trip_df[["Borough", "Zone", "service_zone"]].isnull().sum()
# Out:
# Borough         0
# Zone            0
# service_zone    0
# dtype: int64

# %%
trip_df.head()
trip_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550297 entries, 0 to 550296
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   pickup_hour   550297 non-null  datetime64[us]
#  1   PULocationID  550297 non-null  int64
#  2   ride_count    550297 non-null  int64
#  3   Borough       550297 non-null  object
#  4   Zone          550297 non-null  object
#  5   service_zone  550297 non-null  object
# dtypes: datetime64[us](1), int64(2), object(3)
# memory usage: 25.2+ MB

# %%
weather_df = pd.read_parquet(
    f"{base_path}/weather_cleaned.parquet"
)

weather_df.head()
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   datetime          365 non-null    datetime64[ns]
#  1   temp              365 non-null    float64
#  2   feelslike         365 non-null    float64
#  3   humidity          365 non-null    float64
#  4   precip            365 non-null    float64
#  5   precipprob        365 non-null    int64
#  6   snow              365 non-null    float64
#  7   windgust          365 non-null    float64
#  8   windspeed         365 non-null    float64
#  9   sealevelpressure  365 non-null    float64
#  10  cloudcover        365 non-null    float64
#  11  visibility        365 non-null    float64
#  12  day               365 non-null    int32
#  13  month             365 non-null    int32
#  14  dayofweek         365 non-null    int32
#  15  weekofyear        365 non-null    int64
# ...

# %%
trip_df["date"] = trip_df["pickup_hour"].dt.normalize()

# %%
weather_df["date"] = weather_df["datetime"].dt.normalize()

# %%
final_df = trip_df.merge(
    weather_df.drop(columns=["datetime"]),
    on="date",
    how="left"
)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550297 entries, 0 to 550296
# Data columns (total 25 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   pickup_hour       550297 non-null  datetime64[us]
#  1   PULocationID      550297 non-null  int64
#  2   ride_count        550297 non-null  int64
#  3   Borough           550297 non-null  object
#  4   Zone              550297 non-null  object
#  5   service_zone      550297 non-null  object
#  6   date              550297 non-null  datetime64[us]
#  7   temp              550297 non-null  float64
#  8   feelslike         550297 non-null  float64
#  9   humidity          550297 non-null  float64
#  10  precip            550297 non-null  float64
#  11  precipprob        550297 non-null  int64
#  12  snow              550297 non-null  float64
#  13  windgust          550297 non-null  float64
#  14  windspeed         550297 non-null  float64
# ...

# %%
final_df.isnull().sum()
# Out:
# pickup_hour         0
# PULocationID        0
# ride_count          0
# Borough             0
# Zone                0
# service_zone        0
# date                0
# temp                0
# feelslike           0
# humidity            0
# precip              0
# precipprob          0
# snow                0
# windgust            0
# windspeed           0
# sealevelpressure    0
# cloudcover          0
# visibility          0
# day                 0
# month               0
# dayofweek           0
# weekofyear          0
# is_weekend          0
# quarter             0
# dayofyear           0
# dtype: int64
